# %%
import matplotlib.pyplot as plt

# %%
'''
serial_HFweighted_data = {
    'Serial_Similar_HFweighted': (, ),
    'Serial_Dissimilar_HFweighted': (, ),
    'Serial_Random_HFweighted': (, ),
}

parallel_HFweighted_data = {
    'Parallel_Similar_HFweighted': (, ),
    'Parallel_Dissimilar_HFweighted': (, ),
    'Parallel_Random_HFweighted': (, ),
}

serial_LFweighted_data = {
    'Serial_Similar_LFweighted': (, ),
    'Serial_Dissimilar_LFweighted': (, ),
    'Serial_Random_LFweighted': (, ),
}

parallel_LFweighted_data = {
    'Parallel_Similar_LFweighted': (, ),
    'Parallel_Dissimilar_LFweighted': (, ),
    'Parallel_Random_LFweighted': (, ),
}
'''

serial_noweights_data = {
    #'Serial_Similar': (, ),
    #'Serial_Dissimilar': (, ),
    'Serial_Random': (9, 17141192.696111113),
}

parallel_noweights_data = {
    #'Parallel_Similar': (, ),
    #'Parallel_Dissimilar': (, ),
    'Parallel_Random': (2, 17874085.121666662),
}

serial_nobundling_noweights_data = {
    'Serial LF': (85, 16509928.268710608),
    'Serial HF': (14, 17141192.696111113),
}

parallel_nobundling_noweights_data = {
    'Parallel LF': (100, 16250417.674591016),
    'Parallel HF': (2, 17141192.696111113),
}

# %%
markers = ['o', 's', 'D', '^', 'v', 'x', '*']

# Create the plot
plt.figure(figsize=(10, 6))

# Loop through the dictionary to plot each (x, y) pair
'''
for i, (label, (x, y)) in enumerate(serial_HFweighted_data.items()):
    plt.plot(x, y, marker=markers[i], color='c', label=label)

for i, (label, (x, y)) in enumerate(parallel_HFweighted_data.items()):
    plt.plot(x, y, marker=markers[i], color='m', label=label)

for i, (label, (x, y)) in enumerate(serial_LFweighted_data.items()):
    plt.plot(x, y, marker=markers[i], color='b', label=label)

for i, (label, (x, y)) in enumerate(parallel_LFweighted_data.items()):
    plt.plot(x, y, marker=markers[i], color='g', label=label)
'''

for i, (label, (x, y)) in enumerate(serial_noweights_data.items()):
    plt.plot(x, y, marker=markers[i], color='y', label=label)

for i, (label, (x, y)) in enumerate(parallel_noweights_data.items()):
    plt.plot(x, y, marker=markers[i], color='r', label=label)

for i, (label, (x, y)) in enumerate(serial_nobundling_noweights_data.items()):
    plt.plot(x, y, marker=markers[i+3], color='k', label=label)

for i, (label, (x, y)) in enumerate(parallel_nobundling_noweights_data.items()):
    plt.plot(x, y, marker=markers[i+5], color='k', label=label)

plt.axhline(y=17141192.696111113, color='brown', linestyle=':', label='True Solution')

# Adding titles and labels
plt.title('Serial & Parallel MF-PH for Facility Location: With & Without Random Bundling') # and Model Weights
plt.xlabel('Solution Time (s)')
plt.ylabel('Objective Value')

# Adding a legend
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 1), borderaxespad=0.)

# Show grid
plt.grid()

# Display the plot
#plt.tight_layout()
plt.show()
